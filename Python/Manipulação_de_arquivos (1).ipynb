# %% [markdown]
# # Manipulação de arquivos

# %%
with open('frase1.txt', 'r') as texto:
  for linha in texto:
    print(linha)
# Out:
# OlÃ¡
#
# Estou aprendendo
#
# a linguagem Python
#
# E estou gostando muito

# %%
with open('frase1.txt') as tex:
  r = tex.readlines()

# %%
r
# Out:
# ['\n',
#  'OlÃ¡\n',
#  'Estou aprendendo \n',
#  'a linguagem Python\n',
#  'E estou gostando muito']

# %%
with open('texto2.txt', 'w') as texto:
  texto.write('Olá a todos')

# %%
with open('texto2.txt', 'r') as tex:
  for linha in tex:
    print(linha)
# Out:
# Olá a todos
